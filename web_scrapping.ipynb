# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %%
with open('tablets.html','r',encoding='utf-8') as f:
    html=f.read()

# %%
soup=BeautifulSoup(html,'lxml')

# %%
print(soup.prettify())
# Out:
# <html class="way-item-finder" lang="en" style="--window-width: 1036;">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width" name="viewport"/>
#   <title>
#    Tablets Price List in India (Sep 2023) | Smartprix
#   </title>
#   <link href="/sm-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <meta content="#4692F0" name="theme-color"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <meta content="171761809591603" property="fb:app_id"/>
#   <meta content="max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
#   <link href="https://www.smartprix.com/tablets" rel="canonical"/>
#   <meta content="Smartprix" property="og:site_name"/>
#   <meta content="@smartprix" name="twitter:site"/>
#   <meta content="@smartprix" name="twitter:creator"/>
#   <meta content="summary" name="twitter:card"/>
#   <link href="/smartprix_search.xml" rel="search" title="Smartprix Search: Find the best price" type="application/opensearchdescription+xml"/>
#   <script type="application/ld+json">
#    {"@type":"Organization","@context":"http://schema.org/","@id":"https://www.smartprix.com#organization","name":"Smartprix","url":"https://www.smartprix.com","sameAs":["https://www.facebook.com/smartprix","https://www.instagram.com/smartprix/","https://www.linkedin.com/company/smartprix/","https://plus.google.com/102248368379090638322","https://www.pinterest.com/smartprixcom/","https://twitter.com/smartprix","https://www.youtube.com/channel/UCvkQPgMQX_C1i9JnDZmOY2Q","https://t.me/Smartprix_Deals"],"logo":"https://www.smartprix.com/smartprix.png"}
#   </script>
#   <script type="application/ld+json">
#    {"@type":"Website","@context":"http://schema.org/","@id":"https://www.smartprix.com#website","url":"https://www.smartprix.com","potentialAction":{"@type":"SearchAction","target":"https://www.smartprix.com/products/?q={search_term}","query-input":"required name=search_term"}}
#   </script>
#   <script type="application/ld+json">
#    {"@context":"http://schema.org/","@type":"ItemList","itemListElement":[{"@type":"ListItem","additionalType":"Product","position":1,"name":"OnePlus Pad Go Tablet","url":"https://www.smartprix.com/tablets/oneplus-pad-go-tablet-ppd1aclt2au2","image":["https://cdn1.smartprix.com/rx-iEgfigChi-w1200-h1200/EgfigChi.webp"]},{"@type":"ListItem","additionalType":"Product","position":2,"name":"Lenovo Xiaoxin Pad Pro 12.7","url":"https://www.smartprix.com/tablets/lenovo-xiaoxin-pad-pro-12-7-ppd1f7jb944k","image":["https://cdn1.smartprix.com/rx-isH9pULQB-w1200-h1200/sH9pULQB.webp"]},{"@type":"ListItem","additionalType":"Product","position":3,"name":"Xiaomi Pad 6 Tablet (8GB RAM + 256GB)","url":"https://www.smartprix.com/tablets/xiaomi-pad-6-tablet-8gb-ram-256gb-ppd1apei9st9","image":["https://cdn1.smartprix.com/rx-i8Nq2WSEZ-w1200-h1200/8Nq2WSEZ.webp"]},{"@type":"ListItem","additionalType":"Product","position":4,"name":"Samsung Galaxy Tab S9 FE Plus","url":"https://www.smartprix.com/tablets/samsung-galaxy-tab-s9-fe-plus-ppd1ljbhgy6s","image":["https://cdn1.smartprix.com/rx-iTg7HsDba-w1200-h1200/Tg7HsDba.webp"]},{"@type":"ListItem","additionalType":"Product","position":5,"name":"Xiaomi Redmi Pad SE Tablet","url":"https://www.smartprix.com/tablets/redmi-pad-se-tablet-ppd15o1g3iwr","image":["https://cdn1.smartprix.com/rx-iutQgqfnl-w1200-h1200/utQgqfnl.webp"]},{"@type":"ListItem","additionalType":"Product","position":6,"name":"Realme Pad 2 Tablet","url":"https://www.smartprix.com/tablets/realme-pad-2-tablet-ppd1ravjah9w","image":["https://cdn1.smartprix.com/rx-idfFw5IKW-w1200-h1200/dfFw5IKW.webp"]},{"@type":"ListItem","additionalType":"Product","position":7,"name":"Lenovo Xiaoxin Pad Pro 12.7","url":"https://www.smartprix.com/tablets/lenovo-xiaoxin-pad-pro-12-ppd1jfpql93o","image":["https://cdn1.smartprix.com/rx-iBADXWSjw-w1200-h1200/BADXWSjw.webp"]},{"@type":"ListItem","additionalType":"Product","position":8,"name":"Xiaomi Pad 6 Pro Tablet","url":"https://www.smartprix.com/tablets/xiaomi-pad-6-pro-tablet-ppd1z19z38ym","image":["https://cdn1.smartprix.com/rx-iCOfK7z6T-w1200-h1200/COfK7z6T.webp"]},{"@type":"ListItem","additionalType":"Product","position":9,"name":"Samsung Galaxy Tab A9 Plus Tablet","url":"https://www.smartprix.com/tablets/samsung-galaxy-tab-a9-plus-tablet-ppd18xg0tzyg","image":["https://cdn1.smartprix.com/rx-i07EEFXCt-w1200-h1200/07EEFXCt.webp"]},{"@type":"ListItem","additionalType":"Product","position":10,"name":"Realme Pad X Tablet (6GB RAM+ 128GB)","url":"https://www.smartprix.com/tablets/realme-pad-x-tablet-6gb-ram-128gb-ppd1mj7dchuo","image":["https://cdn1.smartprix.com/rx-iicXW8d3O-w1200-h1200/icXW8d3O.webp"]},{"@type":"ListItem","additionalType":"Product","position":11,"name":"Samsung Galaxy Tab S9 FE","url":"https://www.smartprix.com/tablets/samsung-galaxy-tab-s9-fe-ppd1gwqic3xt","image":["https://cdn1.smartprix.com/rx-idsrgGRW3-w1200-h1200/dsrgGRW3.webp"]},{"@type":"ListItem","additionalType":"Product","position":12,"name":"Honor Pad X9","url":"https://www.smartprix.com/tablets/honor-pad-x9-ppd1zfvn7twz","image":["https://cdn1.smartprix.com/rx-iFhOubHQ0-w1200-h1200/FhOubHQ0.webp"]},{"@type":"ListItem","additionalType":"Product","position":13,"name":"Samsung Galaxy Tab A8 10.5 2021 Tablet (4GB RAM + 64GB)","url":"https://www.smartprix.com/tablets/samsung-galaxy-tab-a8-10-5-2021-tablet-4gb-ppd114i67b81","image":["https://cdn1.smartprix.com/rx-i8aobHEon-w1200-h1200/8aobHEon.webp"]},{"@type":"ListItem","additionalType":"Product","position":14,"name":"Apple iPad 9th Gen 10.2 2021 Tablet (Wi-Fi+64GB)","url":"https://www.smartprix.com/tablets/apple-ipad-9th-gen-10-2-2021-tablet-wi-fi-ppd15h8hiszg","image":["https://cdn1.smartprix.com/rx-iPZ43Te96-w1200-h1200/PZ43Te96.webp"]},{"@type":"ListItem","additionalType":"Product","position":15,"name":"Samsung Galaxy Tab A9 Tablet","url":"https://www.smartprix.com/tablets/samsung-galaxy-tab-a9-tablet-ppd1x6ta8hpv","image":["https://cdn1.smartprix.com/rx-iemNikZaC-w1200-h1200/emNikZaC ...
#   </script>
#   <style>
#    .icon{width:24px;height:24px}
#   </style>
#   <script>
#    window.versions={"js":"2.0","pkg":"0.14.9"}
#   </script>
#   <script>
#    !function(){var e=window,t=document,i=e.location,n=t.documentElement,r=n.style,a=e._innerWidth=e.innerWidth;if(!("noModule"in HTMLScriptElement.prototype&&e.CSS.supports("caret-color: red")&&e.Promise.prototype.finally))return t.cookie="old=1;expires=Thu, 01 Jan 2037 00:00:00 GMT;domain=.smartprix.com;path=/",void i.replace("?out=old");r.setProperty("--window-width",a),window.addEventListener("resize",function(){a=e._innerWidth=e.innerWidth,r.setProperty("--window-width",a)},{passive:!0}),(e.Android||navigator.userAgent.includes("SmApp/"))&&n.classList.add("sm-mobile-app");var l="data-way";function o(e,t){return e.getAttribute(t)}function s(e){e.preventDefault()}function d(t,n){e.dispatchEvent(new Event("navigate"));var r=e.$smNavigate;if(r)n.$el=t,r(n);else{var a=o(t,"href")||o(t,l);if(!a)return;if(a.startsWith("@"))a=a.replace(/@/g,"/");else if("A"===t.tagName)return;s(n);var d=o(t,"target");d?e.open(a,d):i.href=a}}t.addEventListener("click",function(e){if(!e.$handled){var t=e.ctrlKey||e.shiftKey||e.altKey||e.metaKey,i=e.target,n=o(i,l);if("A"!==i.tagName){var r=i.closest("a");if(r){if(null==(n=o(r,l))||t)return;d(r,e)}else{if(null==n){if(!(i=i.closest("["+l+"]")))return;n=o(i,l)}if(n)d(i,e);else{var a=i.querySelector("a["+l+"]");if(a){s(e);var c=new MouseEvent("click",{ctrlKey:e.ctrlKey,shiftKey:e.shiftKey,altKey:e.altKey,metaKey:e.metaKey,bubbles:!0,cancelable:!0});c.$dataWayEl=i,a.dispatchEvent(c)}}}}else{if(null==n||t)return;d(i,e)}}})}()
#   </script>
#   <link href="/assets/index.46f52f5b.css" rel="stylesheet"/>
#   <link href="/assets/FinderPage.aca6561a.css" rel="stylesheet"/>
#   <link as="image" href="https://cdn1.smartprix.com/rx-iEgfigChi-w280-h280/oneplus-pad-go-table.webp" rel="preload"/>
#   <script crossorigin="" src="/assets/index.9b8ed450.js" type="module">
#   </script>
#   <script crossorigin="" src="/assets/FinderPage.a18fd05a.js" type="module">
#   </script>
#   <link href="https://cdn1.smartprix.com" rel="preconnect"/>
#   <link href="https://analytics.google.com" rel="preconnect"/>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-V14PK7DJZ5">
#   </script>
#   <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#   </script>
#   <link as="script" crossorigin="" href="/assets/FinderPage.a18fd05a.js" rel="modulepreload"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <script async="" src="https://securepubads.g.doubleclick.net/pagead/managed/js/gpt/m202309260101/pubads_impl.js?cb=31078220">
#   </script>
#  </head>
#  <body>
#   <div id="app">
#    <!--[-->
#    <header>
#     <div class="sm-search-header">
#      <div class="sm-search-bar">
#       <svg class="icon i-menu" style="" viewbox="0 0 24 24">
#        <path d="M3,6H21V8H3V6M3,11H21V13H3V11M3,16H21V18H3V16Z">
#        </path>
#       </svg>
#       <svg class="icon i-back" style="" viewbox="0 0 24 24">
#        <path d="M20,11V13H8L13.5,18.5L12.08,19.92L4.16,12L12.08,4.08L13.5,5.5L8,11H20Z">
#        </path>
#       </svg>
#       <a class="logo" data-way="" href="/">
#        <img alt="Smartprix" height="60" src="/img/sm_small.png" width="186"/>
#       </a>
#       <form action="/products" autocomplete="off" method="get">
#        <div class="sm-input type-text no-label">
#         <!-- -->
#         <input aria-label="Search" class="input empty" name="q" placeholder="Search for products, brands &amp; more ..." type="text" value=""/>
#         <!-- -->
#         <!-- -->
#        </div>
#        <svg class="icon i-search" style="" viewbox="0 0 24 24">
#         <path d="M9.5,3A6.5,6.5 0 0,1 16,9.5C16,11.11 15.41,12.59 14.44,13.73L14.71,14H15.5L20.5,19L19,20.5L14,15.5V14.71L13.73,14.44C12.59,15.41 11.11,16 9.5,16A6.5,6.5 0 0,1 3,9.5A6.5,6.5 0 0,1 9.5,3M9.5,5C7,5 5,7 5,9.5C5,12 7,14 9.5,14C12,14 14,12 14,9.5C14,7 12,5 9.5,5Z">
#         </path>
#        </svg>
#       </form>
#       <!-- -->
#       <svg class="icon i-vert" style="" viewbox="0 0 24 24">
#        <path d="M12,16A2,2 0 0,1 14,18A2,2 0 0,1 12,20A2,2 0 0,1 10,18A2,2 0 0,1 12,16M12,10A2,2 0 0,1 14,12A2,2 0 0,1 12,14A2,2 0 0,1 10,12A2,2 0 0,1 12,10M12,4A2,2 0 0,1 14,6A2,2 0 0,1 12,8A2,2 0 0,1 10,6A2,2 0 0,1 12,4Z">
#        </path>
#       </svg>
#      </div>
#      <div class="sm-desktop-header-right">
#       <!-- -->
#       <div class="sm-dropdown sm-d-header-user">
#        <!--[-->
#        <svg class="icon" style="" viewbox="0 0 24 24">
#         <path d="M12,19.2C9.5,19.2 7.29,17.92 6,16C6.03,14 10,12.9 12,12.9C14,12.9 17.97,14 18,16C16.71,17.92 14.5,19.2 12,19.2M12,5A3,3 0 0,1 15,8A3,3 0 0,1 12,11A3,3 0 0,1 9,8A3,3 0 0,1 12,5M12,2A10,10 0 0,0 2,12A10,10 0 0,0 12,22A10,10 0 0,0 22,12C22,6.47 17.5,2 12,2Z">
#         </path>
#        </svg>
#        <span>
#         Login
#        </span>
#        <!--]-->
#        <svg class="icon d" style="" viewbox="0 0 24 24">
#         <path d="M7.41,8.58L12,13.17L16.59,8.58L18,10L12,16L6,10L7.41,8.58Z">
#         </path>
#        </svg>
#        <div class="x">
#         <!--[-->
#         <div class="sm-menu">
#          <!--[-->
#          <!--[-->
#          <a class="" href="/login" role="button">
#           <svg class="icon" style="" viewbox="0 0 24 24">
#            <path d="M14,12L10,8V11H2V13H10V16M20,18V6C20,4.89 19.1,4 18,4H6A2,2 0 0,0 4,6V9H6V6H18V18H6V15H4V18A2,2 0 0,0 6,20H18A2,2 0 0,0 20,18Z">
#            </path>
#           </svg>
#           <span class="text">
#            Login
#           </span>
#           <!-- -->
#          </a>
#          <!--]-->
#          <!--[-->
#          <a class="" href="/signup" role="button">
#           <svg class="icon" style="" viewbox="0 0 24 24">
#            <path d="M12,19.2C9.5,19.2 7.29,17.92 6,16C6.03,14 10,12.9 12,12.9C14,12.9 17.97,14 18,16C16.71,17.92 14.5,19.2 12,19.2M12,5A3,3 0 0,1 15,8A3,3 0 0,1 12,11A3,3 0 0,1 9,8A3,3 0 0,1 12,5M12,2A10,10 0 0,0 2,12A10,10 0 0,0 12,22A10,10 0 0,0 22,12C22,6.47 17.5,2 12,2Z">
#            </path>
#           </svg>
#           <span class="text">
#            Signup
#           </span>
#           <!-- -->
#          </a>
#          <!--]-->
#          <!--]-->
#         </div>
#         <!--]-->
#        </div>
#       </div>
#       <div class="sm-dropdown sm-d-header-more">
#        <!--[-->
#        More
#        <!--]-->
#        <svg class="icon d" style="" viewbox="0 0 24 24">
#         <path d="M7.41,8.58L12,13.17L16.59,8.58L18,10L12,16L6,10L7.41,8.58Z">
#         </path>
#        </svg>
#        <div class="x">
#         <!--[-->
#         <div class="sm-menu">
#          <!--[-->
#          <!--[-->
#          <a class="" href="/about/contact" rel="nofollow noopener" role="button" target="_blank">
#           <svg class="icon" style="" viewbox="0 0 24 24">
#            <path d="M20,8L12,13L4,8V6L12,11L20,6M20,4H4C2.89,4 2,4.89 2,6V18A2,2 0 0,0 4,20H20A2,2 0 0,0 22,18V6C22,4.89 21.1,4 20,4Z">
#            </path>
#           </svg>
#           <span class="text">
#            Contact Us
#           </span>
#           <!-- -->
#          </a>
#          <!--]-->
#          <!--[-->
#          <a class="" href="https://www.facebook.com/smartprix" rel="nofollow noopener" role="button" target="_blank">
#           <svg class="icon" style="" viewbox="0 0 24 24">
#            <path d="M12 2.04C6.5 2.04 2 6.53 2 12.06C2 17.06 5.66 21.21 10.44 21.96V14.96H7.9V12.06H10.44V9.85C10.44 7.34 11.93 5.96 14.22 5.96C15.31 5.96 16.45 6.15 16.45 6.15V8.62H15.19C13.95 8.62 13.56 9.39 13.56 10.18V12.06H16.34L15.89 14.96H13.56V21.96A10 10 0 0 0 22 12.06C22 6.53 17.5 2.04 12 2.04Z">
#            </path>
#           </svg>
#           <span class="text">
#            Facebook
#           </span>
#           <!-- -->
#          </a>
#          <!--]-->
#          <!--[-->
#          <a class="" href="https://twitter.com/smartprix" rel="nofollow noopener" role="button" target="_blank">
#           <svg class="icon" style="" viewbox="0 0 24 24">
#            <path d="M22.46,6C21.69,6.35 20.86,6.58 20,6.69C20.88,6.16 21.56,5.32 21.88,4.31C21.05,4.81 20.13,5.16 19.16,5.36C18.37,4.5 17.26,4 16,4C13.65,4 11.73,5.92 11.73,8.29C11.73,8.63 11.77,8.96 11.84,9.27C8.28,9.09 5.11,7.38 3,4.79C2.63,5.42 2.42,6.16 2.42,6.94C2.42,8.43 3.17,9.75 4.33,10.5C3.62,10.5 2.96,10.3 2.38,10C2.38,10 2.38,10 2.38,10.03C2.38,12.11 3.86,13.85 5.82,14.24C5.46,14.34 5.08,14.39 4.69,14.39C4.42,14.39 4.15,14.36 3.89,14.31C4.43,16 6,17.26 7.89,17.29C6.43,18.45 4.58,19.13 2.56,19.13C2.22,19.13 1.88,19.11 1.54,19.07C3.44,20.29 5.7,21 8.12,21C16,21 20.33,14.46 20.33,8.79C20.33,8.6 20.33,8.42 20.32,8.23C21.16,7.63 21.88,6.87 22.46,6Z">
#            </path>
#           </svg>
#           <span class="text">
#            Twitter
#           </span>
#           <!-- -->
#          </a>
#          <!--]-->
#          <!--[-->
#          <a class="" href="https://www.youtube.com/channel/UCvkQPgMQX_C1i9JnDZmOY2Q" rel="nofollow noopener" role="button" target="_blank">
#           <svg class="icon" style="" viewbox="0 0 24 24">
#            <path d="M10,15L15.19,12L10,9V15M21.56,7.17C21.69,7.64 21.78,8.27 21.84,9.07C21.91,9.87 21.94,10.56 21.94,11.16L22,12C22,14.19 21.84,15.8 21.56,16.83C21.31,17.73 20.73,18.31 19.83,18.56C19.36,18.69 18.5,18.78 17.18,18.84C15.88,18.91 14.69,18.94 13.59,18.94L12,19C7.81,19 5.2,18.84 4.17,18.56C3.27,18.31 2.69,17.73 2.44,16.83C2.31,16.36 2.22,15.73 2.16,14.93C2.09,14.13 2.06,13.44 2.06,12.84L2,12C2,9.81 2.16,8.2 2.44,7.17C2.69,6.27 3.27,5.69 4.17,5.44C4.64,5.31 5.5,5.22 6.82,5.16C8.12,5.09 9.31,5.06 10.41,5.06L12,5C16.19,5 18.8,5.16 19.83,5.44C20.73,5.69 21.31,6.27 21.56,7.17Z">
#            </path>
#           </svg>
#           <span class="text">
#            YouTube
#           </span>
#           <!-- -->
#          </a>
#          <!--]-->
#          <!--[-->
#          <a class="" href="https://www.instagram.com/smartprix/" rel="nofollow noopener" role="button" target="_blank">
#           <svg class="icon" style="" viewbox="0 0 24 24">
#            <path d="M7.8,2H16.2C19.4,2 22,4.6 22,7.8V16.2A5.8,5.8 0 0,1 16.2,22H7.8C4.6,22 2,19.4 2,16.2V7.8A5.8,5.8 0 0,1 7.8,2M7.6,4A3.6,3.6 0 0,0 4,7.6V16.4C4,18.39 5.61,20 7.6,20H16.4A3.6,3.6 0 0,0 20,16.4V7.6C20,5.61 18.39,4 16.4,4H7.6M17.25,5.5A1.25,1.25 0 0,1 18.5,6.75A1.25,1.25 0 0,1 17.25,8A1.25,1.25 0 0,1 16,6.75A1.25,1.25 0 0,1 17.25,5.5M12,7A5,5 0 0,1 17,12A5,5 0 0,1 12,17A5,5 0 0,1 7,12A5,5 0 0,1 12,7M12,9A3,3 0 0,0 9,12A3,3 0 0,0 12,15A3,3 0 0,0 15,12A3,3 0 0,0 12,9Z">
#            </path>
#           </svg>
#           <span class="text">
#            Instagram
#           </span>
#           <!-- -->
#          </a>
#          <!--]-->
#          <!--[-->
#          <a class="" href="https://smpx.to/telegram?utm_source=desktop_top_menu" rel="nofollow noopener" role="button" target="_blank">
#           <svg class="icon" style="" viewbox="0 0 24 24">
#            <path d="M20.7 3.7 2.9 10.6c-1.2.4-1.2 1.1-.2 1.4l4.6 1.4 10.5-6.6c.5-.3 1-.1.6.2l-8.6 7.7-.3 4.7c.5 0 .7-.2 1-.5l2.2-2.1 4.6 3.4c.8.4 1.4.2 1.6-.8l3-14.2c.4-1.3-.4-1.8-1.2-1.5z">
#            </path>
#           </svg>
#           <span class="text">
#            Telegram
#           </span>
#           <!-- -->
#          </a>
#          <!--]-->
#          <!--[-->
#          <a class="" href="https://smpx.to/app?utm_source=desktop_top_menu" rel="nofollow noopener" role="button" target="_blank">
#           <svg class="icon" style="" viewbox="0 0 24 24">
#            <path d="M3,20.5V3.5C3,2.91 3.34,2.39 3.84,2.15L13.69,12L3.84,21.85C3.34,21.6 3,21.09 3,20.5M16.81,15.12L6.05,21.34L14.54,12.85L16.81,15.12M20.16,10.81C20.5,11.08 20.75,11.5 20.75,12C20.75,12.5 20.53,12.9 20.18,13.18L17.89,14.5L15.39,12L17.89,9.5L20.16,10.81M6.05,2.66L16.81,8.88L14.54,11.15L6.05,2.66Z">
#            </path>
#           </svg>
#           <span class="text">
#            Android App
#           </span>
#           <!-- -->
#          </a>
#          <!--]-->
#          <!--]-->
#         </div>
#         <!--]-->
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="sm-top-tabs only-mobile">
#      <a aria-label="Home" data-way="" href="/" style="flex:0 0 15vw;">
#       <svg class="icon" style="top:-1px;" viewbox="0 0 24 24">
#        <path d="M10,20V14H14V20H19V12H22L12,3L2,12H5V20H10Z">
#        </path>
#       </svg>
#      </a>
#      <a data-way="" href="/mobiles">
#       Mobiles
#      </a>
#      <a data-way="" href="/laptops">
#       Laptops
#      </a>
#      <a data-way="" href="/tvs" style="flex:0 0 15vw;">
#       TVs
#      </a>
#      <a data-way="" href="/deals">
#       Deals
#      </a>
#     </div>
#    </header>
#    <nav class="sm-desktop-nav">
#     <ul>
#      <!--[-->
#      <li>
#       <a data-way="" href="/mobiles">
#        Mobiles
#       </a>
#      </li>
#      <li>
#       <a data-way="" href="/tablets">
#        Tablets
#       </a>
#      </li>
#      <li>
#       <a data-way="" href="/laptops">
#        Laptops
#       </a>
#      </li>
#      <li>
#       <a data-way="" href="/tvs">
#        TVs
#       </a>
#      </li>
#      <li>
#       <div class="sm-dropdown">
#        <!--[-->
#        Electronics
#        <!--]-->
#        <svg class="icon d" style="" viewbox="0 0 24 24">
#         <path d="M7.41,8.58L12,13.17L16.59,8.58L18,10L12,16L6,10L7.41,8.58Z">
#         </path>
#        </svg>
#        <div class="x">
#         <!--[-->
#         <div class="sm-menu sm-dn-menu">
#          <!--[-->
#          <!--[-->
#          <a class="" href="/cameras" role="button">
#           <img alt="Cameras" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-iR6SKymCH-w50-h50/R6SKymCH.webp"/>
#           <span class="text">
#            Cameras
#           </span>
#           <!-- -->
#          </a>
#          <!--]-->
#          <!--[-->
#          <a class="" href="/smartwatches" role="button">
#           <img alt="Smart Watches" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-iXjxQXvn2-w50-h50/XjxQXvn2.webp"/>
#           <span class="text">
#            Smart Watches
#           </span>
#           <!-- -->
#          </a>
#          <!--]-->
#          <!--[-->
#          <a class="" href="/fitness_bands" role="button">
#           <img alt="Fitness Bands" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-idKuDT9nG-w50-h50/dKuDT9nG.webp"/>
#           <span class="text">
#            Fitness Bands
#           </span>
#           <!-- -->
#          </a>
#          <!--]-->
#          <!--[-->
#          <a class="" href="/vr_headsets" role="button">
#           <img alt="VR Headsets" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-iQpmE0d60-w50-h50/QpmE0d60.webp"/>
#           <span class="text">
#            VR Headsets
#           </span>
#           <!-- -->
#          </a>
#          <!--]-->
#          <a class="subHeading" href="/gaming" role="button">
#           <!-- -->
#           <span class="text">
#            Gaming
#           </span>
#           <!-- -->
#          </a>
#          <a class="" href="/gaming_consoles" role="button">
#           <img alt="Gaming Consoles" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-iKaJPyErU-w50-h50/KaJPyErU.webp"/>
#           <span class="text">
#            Gaming Consoles
#           </span>
#           <!-- -->
#          </a>
#          <a class="" href="/gamepads_joysticks" role="button">
#           <img alt="Gamepads and Joysticks" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-ihQYREPo3-w50-h50/hQYREPo3.webp"/>
#           <span class="text">
#            Gamepads and Joysticks
#           </span>
#           <!-- -->
#          </a>
#          <!--]-->
#         </div>
#         <!--]-->
#        </div>
#       </div>
#      </li>
#      <li>
#       <div class="sm-dropdown">
#        <!--[-->
#        Appliances
#        <!--]-->
#        <svg class="icon d" style="" viewbox="0 0 24 24">
#         <path d="M7.41,8.58L12,13.17L16.59,8.58L18,10L12,16L6,10L7.41,8.58Z">
#         </path>
#        </svg>
#        <div class="x">
#         <!--[-->
#         <div class="sm-menu sm-dn-menu">
#          <!--[-->
#          <!--[-->
#          <div class="sm-menu-column" style="--n: 1;">
#           <a class="title" href="/appliances" role="button">
#            Home Appliances
#           </a>
#           <div class="sm-menu">
#            <a class="subHeading" href="/large_appliances" role="button">
#             <!-- -->
#             <span class="text">
#              Large Appliances
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/air_conditioners" role="button">
#             <img alt="ACs" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-ikAfBBj8K-w50-h50/kAfBBj8K.webp"/>
#             <span class="text">
#              ACs
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/refrigerators" role="button">
#             <img alt="Refrigerators" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-i0g6nr7Fk-w50-h50/0g6nr7Fk.webp"/>
#             <span class="text">
#              Refrigerators
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/washing_machines" role="button">
#             <img alt="Washing Machines" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-iY7efj6YN-w50-h50/Y7efj6YN.webp"/>
#             <span class="text">
#              Washing Machines
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/air_coolers" role="button">
#             <img alt="Air Coolers" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-ivwk35nJd-w50-h50/vwk35nJd.webp"/>
#             <span class="text">
#              Air Coolers
#             </span>
#             <!-- -->
#            </a>
#            <a class="subHeading" href="/small_appliances" role="button">
#             <!-- -->
#             <span class="text">
#              Small Appliances
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/geysers" role="button">
#             <img alt="Geysers" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-iYsznAG1c-w50-h50/YsznAG1c.webp"/>
#             <span class="text">
#              Geysers
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/irons" role="button">
#             <img alt="Irons" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-iw3LJv7Xj-w50-h50/w3LJv7Xj.webp"/>
#             <span class="text">
#              Irons
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/vacuum_cleaners" role="button">
#             <img alt="Vacuum Cleaners" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-iOkjF2xkK-w50-h50/OkjF2xkK.webp"/>
#             <span class="text">
#              Vacuum Cleaners
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/air_purifiers" role="button">
#             <img alt="Air Purifiers" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-i9TTh2HMF-w50-h50/9TTh2HMF.webp"/>
#             <span class="text">
#              Air Purifiers
#             </span>
#             <!-- -->
#            </a>
#           </div>
#          </div>
#          <!--]-->
#          <!--[-->
#          <div class="sm-menu-column" style="--n: 2;">
#           <a class="title" href="/kitchen_appliances" role="button">
#            Kitchen Appliances
#           </a>
#           <div class="sm-menu">
#            <a class="" href="/mixer_juicer_grinders" role="button">
#             <img alt="Mixer Juicer Grinders" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-ivjWQmBMQ-w50-h50/vjWQmBMQ.webp"/>
#             <span class="text">
#              Mixer Juicer Grinders
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/induction_cooktops" role="button">
#             <img alt="Induction Cooktops" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-iJv0ljssW-w50-h50/Jv0ljssW.webp"/>
#             <span class="text">
#              Induction Cooktops
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/microwave_ovens" role="button">
#             <img alt="Microwave Ovens" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-iIRihGEr4-w50-h50/IRihGEr4.webp"/>
#             <span class="text">
#              Microwave Ovens
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/sandwich_makers" role="button">
#             <img alt="Sandwich Makers" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-isbEAudFW-w50-h50/sbEAudFW.webp"/>
#             <span class="text">
#              Sandwich Makers
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/chimneys" role="button">
#             <img alt="Chimneys" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-i51PkyNRa-w50-h50/51PkyNRa.webp"/>
#             <span class="text">
#              Chimneys
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/hand_blenders" role="button">
#             <img alt="Hand Blenders" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-i4Kh7dYLl-w50-h50/4Kh7dYLl.webp"/>
#             <span class="text">
#              Hand Blenders
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/electric_kettles" role="button">
#             <img alt="Electric Kettles" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-i8uNCC0eg-w50-h50/8uNCC0eg.webp"/>
#             <span class="text">
#              Electric Kettles
#             </span>
#             <!-- -->
#            </a>
#           </div>
#          </div>
#          <!--]-->
#          <!--[-->
#          <div class="sm-menu-column" style="--n: 3;">
#           <a class="title" href="/personal_appliances" role="button">
#            Personal Appliances
#           </a>
#           <div class="sm-menu">
#            <a class="" href="/trimmers" role="button">
#             <img alt="Trimmers" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-iWGexWJa5-w50-h50/WGexWJa5.webp"/>
#             <span class="text">
#              Trimmers
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/shavers" role="button">
#             <img alt="Shavers" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-izpQuRpzB-w50-h50/zpQuRpzB.webp"/>
#             <span class="text">
#              Shavers
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/epilators" role="button">
#             <img alt="Epilators" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-idlDvBDCD-w50-h50/dlDvBDCD.webp"/>
#             <span class="text">
#              Epilators
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/hair_dryers" role="button">
#             <img alt="Hair Dryers" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-iCTuWIn78-w50-h50/CTuWIn78.webp"/>
#             <span class="text">
#              Hair Dryers
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/hair_straighteners" role="button">
#             <img alt="Hair Straighteners" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-iSI4lyvrx-w50-h50/SI4lyvrx.webp"/>
#             <span class="text">
#              Hair Straighteners
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/hair_curlers" role="button">
#             <img alt="Hair Curlers" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-iLvqqM1Ch-w50-h50/LvqqM1Ch.webp"/>
#             <span class="text">
#              Hair Curlers
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/power_toothbrushes" role="button">
#             <img alt="Electric Toothbrushes" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-idKT70plj-w50-h50/dKT70plj.webp"/>
#             <span class="text">
#              Electric Toothbrushes
#             </span>
#             <!-- -->
#            </a>
#           </div>
#          </div>
#          <!--]-->
#          <!--]-->
#         </div>
#         <!--]-->
#        </div>
#       </div>
#      </li>
#      <li>
#       <div class="sm-dropdown">
#        <!--[-->
#        Computers
#        <!--]-->
#        <svg class="icon d" style="" viewbox="0 0 24 24">
#         <path d="M7.41,8.58L12,13.17L16.59,8.58L18,10L12,16L6,10L7.41,8.58Z">
#         </path>
#        </svg>
#        <div class="x">
#         <!--[-->
#         <div class="sm-menu sm-dn-menu">
#          <!--[-->
#          <!--[-->
#          <div class="sm-menu-column" style="--n: 1;">
#           <a class="title" href="/computers" role="button">
#            Categories
#           </a>
#           <div class="sm-menu">
#            <a class="" href="/laptops" role="button">
#             <img alt="Laptops" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-i6invpMY2-w50-h50/6invpMY2.webp"/>
#             <span class="text">
#              Laptops
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/computers" role="button">
#             <img alt="Computers" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-icT3NlIpX-w50-h50/cT3NlIpX.webp"/>
#             <span class="text">
#              Computers
#             </span>
#             <!-- -->
#            </a>
#            <a class="subHeading" href="/computer_components" role="button">
#             <!-- -->
#             <span class="text">
#              Computer Components
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/computer_ram" role="button">
#             <img alt="RAM" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-igMPXd20R-w50-h50/gMPXd20R.webp"/>
#             <span class="text">
#              RAM
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/computer_processors" role="button">
#             <img alt="Processors (CPU)" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-injGqQL2L-w50-h50/njGqQL2L.webp"/>
#             <span class="text">
#              Processors (CPU)
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/computer_psu" role="button">
#             <img alt="PSU" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-idIbqmrWZ-w50-h50/dIbqmrWZ.webp"/>
#             <span class="text">
#              PSU
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/computer_motherboards" role="button">
#             <img alt="MotherBoards" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-iELrt31FB-w50-h50/ELrt31FB.webp"/>
#             <span class="text">
#              MotherBoards
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/computer_graphic_cards" role="button">
#             <img alt="Graphics Cards" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-iJfLvU07g-w50-h50/JfLvU07g.webp"/>
#             <span class="text">
#              Graphics Cards
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/internal_hard_drives" role="button">
#             <img alt="Internal Hard Drives" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-inEGNYLtd-w50-h50/nEGNYLtd.webp"/>
#             <span class="text">
#              Internal Hard Drives
#             </span>
#             <!-- -->
#            </a>
#           </div>
#          </div>
#          <!--]-->
#          <!--[-->
#          <div class="sm-menu-column" style="--n: 2;">
#           <a class="title" href="/computer_peripherals" role="button">
#            Other Accessories
#           </a>
#           <div class="sm-menu">
#            <a class="subHeading" href="/computer_peripherals" role="button">
#             <!-- -->
#             <span class="text">
#              Computer Peripherals
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/monitors" role="button">
#             <img alt="Monitors" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-im0kKhjVX-w50-h50/m0kKhjVX.webp"/>
#             <span class="text">
#              Monitors
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/printers" role="button">
#             <img alt="Printers" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-ijxqIRAhf-w50-h50/jxqIRAhf.webp"/>
#             <span class="text">
#              Printers
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/projectors" role="button">
#             <img alt="Projectors" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-i8lyIcovn-w50-h50/8lyIcovn.webp"/>
#             <span class="text">
#              Projectors
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/routers_modems" role="button">
#             <img alt="Routers &amp; Modems" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-iAafBn99j-w50-h50/AafBn99j.webp"/>
#             <span class="text">
#              Routers &amp; Modems
#             </span>
#             <!-- -->
#            </a>
#            <a class="subHeading" href="/audio_video" role="button">
#             <!-- -->
#             <span class="text">
#              Audio and Video
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/home_theaters" role="button">
#             <img alt="Home Theaters" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-ilmqxw76d-w50-h50/lmqxw76d.webp"/>
#             <span class="text">
#              Home Theaters
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/computer_headphones" role="button">
#             <img alt="Computer Headphones" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-iPAoBW8EN-w50-h50/PAoBW8EN.webp"/>
#             <span class="text">
#              Computer Headphones
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/computer_speakers" role="button">
#             <img alt="Computer Speakers" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-iUVnL2sIz-w50-h50/UVnL2sIz.webp"/>
#             <span class="text">
#              Computer Speakers
#             </span>
#             <!-- -->
#            </a>
#           </div>
#          </div>
#          <!--]-->
#          <!--]-->
#         </div>
#         <!--]-->
#        </div>
#       </div>
#      </li>
#      <li>
#       <div class="sm-dropdown">
#        <!--[-->
#        Accessories
#        <!--]-->
#        <svg class="icon d" style="" viewbox="0 0 24 24">
#         <path d="M7.41,8.58L12,13.17L16.59,8.58L18,10L12,16L6,10L7.41,8.58Z">
#         </path>
#        </svg>
#        <div class="x">
#         <!--[-->
#         <div class="sm-menu sm-dn-menu">
#          <!--[-->
#          <!--[-->
#          <div class="sm-menu-column" style="--n: 1;">
#           <a class="title" href="/mobile_accessories" role="button">
#            Mobile Accessories
#           </a>
#           <div class="sm-menu">
#            <a class="" href="/mobile_headphones" role="button">
#             <img alt="Headphones And Earphones" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-iUfE0ayqy-w50-h50/UfE0ayqy.webp"/>
#             <span class="text">
#              Headphones And Earphones
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/mobile_cases_covers" role="button">
#             <img alt="Cases And Covers" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-iYf9eCphE-w50-h50/Yf9eCphE.webp"/>
#             <span class="text">
#              Cases And Covers
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/smartwatches" role="button">
#             <img alt="Smart Watches" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-iXjxQXvn2-w50-h50/XjxQXvn2.webp"/>
#             <span class="text">
#              Smart Watches
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/mobile_memory_cards" role="button">
#             <img alt="Memory Cards" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-i7IuuMGLU-w50-h50/7IuuMGLU.webp"/>
#             <span class="text">
#              Memory Cards
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/mobile_speakers" role="button">
#             <img alt="Speakers" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-iKBToyaYW-w50-h50/KBToyaYW.webp"/>
#             <span class="text">
#              Speakers
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/mobile_power_banks" role="button">
#             <img alt="Power Banks" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-i3Tye6YWB-w50-h50/3Tye6YWB.webp"/>
#             <span class="text">
#              Power Banks
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/mobile_chargers" role="button">
#             <img alt="Chargers" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-ik08MxrHp-w50-h50/k08MxrHp.webp"/>
#             <span class="text">
#              Chargers
#             </span>
#             <!-- -->
#            </a>
#            <a class="bold" href="/mobile_accessories" role="button">
#             <!-- -->
#             <span class="text">
#              All Mobile Accessories →
#             </span>
#             <!-- -->
#            </a>
#           </div>
#          </div>
#          <!--]-->
#          <!--[-->
#          <div class="sm-menu-column" style="--n: 2;">
#           <a class="title" href="/laptop_accessories" role="button">
#            Laptop Accessories
#           </a>
#           <div class="sm-menu">
#            <a class="" href="/pen_drives" role="button">
#             <img alt="Pen Drives" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-iAG8zJZDr-w50-h50/AG8zJZDr.webp"/>
#             <span class="text">
#              Pen Drives
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/external_hard_disks" role="button">
#             <img alt="External Hard Disks" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-itCBEKP8a-w50-h50/tCBEKP8a.webp"/>
#             <span class="text">
#              External Hard Disks
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/computer_keyboards" role="button">
#             <img alt="Keyboards" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-idUqgFfX5-w50-h50/dUqgFfX5.webp"/>
#             <span class="text">
#              Keyboards
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/computer_mouse" role="button">
#             <img alt="Mouse" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-izgqdIHdb-w50-h50/zgqdIHdb.webp"/>
#             <span class="text">
#              Mouse
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/computer_webcams" role="button">
#             <img alt="Webcams" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-irtBJuvk0-w50-h50/rtBJuvk0.webp"/>
#             <span class="text">
#              Webcams
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/graphical_tablets" role="button">
#             <img alt="Graphical Tablets" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-iAQaESvS7-w50-h50/AQaESvS7.webp"/>
#             <span class="text">
#              Graphical Tablets
#             </span>
#             <!-- -->
#            </a>
#            <a class="" href="/laptop_batteries" role="button">
#             <img alt="Laptop Batteries" class="sm-img" loading="lazy" src="https://cdn1.smartprix.com/rx-i9Fe6Ogtp-w50-h50/9Fe6Ogtp.webp"/>
#             <span class="text">
#              Laptop Batteries
#             </span>
#             <!-- -->
#            </a>
#            <a class="bold" href="/laptop_accessories" role="button">
#             <!-- -->
#             <span class="text">
#              All Laptop Accessories →
#             </span>
#             <!-- -->
#            </a>
#           </div>
#          </div>
#          <!--]-->
#          <!--]-->
#         </div>
#         <!--]-->
#        </div>
#       </div>
#      </li>
#      <li>
#       <a data-way="" href="/deals">
#        Deals
#       </a>
#      </li>
#      <li>
#       <a data-way="" href="/bytes/">
#        News
#       </a>
#      </li>
#      <li>
#       <a data-way="" href="/amazon-hub">
#        Amazon Hub
#       </a>
#      </li>
#      <!--]-->
#     </ul>
#    </nav>
#    <!-- -->
#    <!-- -->
#    <!-- -->
#    <!-- -->
#    <!-- -->
#    <main class="pg-prf aside-320 aside-left aside-imp">
#     <div>
#      <div class="sm-box" style="">
#       <!-- -->
#       <!--[-->
#       <h1>
#        Tablets Price List in India
#       </h1>
#       <div class="sm-desc">
#        <div class="sm-content">
#         <p>
#          Discover our extensive collection of the best tablets available online in India, all at the lowest prices. If you're looking for a device with a big screen and a mobile operating system, a tablet may be perfect for you. Tablets are ideal for those who want a secondary screen for reading, browsing, watching movies or TV shows, scrolling through social media apps, and, most importantly, for enhancing the gaming experience with clear visuals and high-quality graphics. With a wide range of tablets available in different designs and price ranges, buyers can easily find the right tablet to meet their budget and demands.
#         </p>
#         <p>
#          We have curated a list of all the latest and upcoming tablets from top brands such as Apple, Samsung, Oppo, Vivo, and many more. Our list includes detailed specifications and features, making it easier for you to select the right tablet for your needs. You can also compare tablets from different brands based on price, specs, and features. Our price list is updated regularly to ensure that you always have access to the latest information. Check out our collection now to find the perfect tablet for you. This price list was last updated on September 28, 2023.
#         </p>
#         <p>
#          <strong>
#           Also See
#          </strong>
#          :
#          <a href="https://www.smartprix.com/tablets/apple-brand" target="_blank">
#           Apple iPads
#          </a>
#          •
#          <a href="https://www.smartprix.com/tablets/samsung-brand" target="_blank">
#           Samsung Tablets
#          </a>
#          •
#          <a href="https://www.smartprix.com/tablets/lenovo-brand" target="_blank">
#           Lenovo Tablets
#          </a>
#          •
#          <a href="https://www.smartprix.com/tablets/xiaomi-brand" target="_blank">
#           Xiaomi Tablets
#          </a>
#          •
#          <a href="https://www.smartprix.com/tablets/realme-brand" target="_blank">
#           Realme Tablets
#          </a>
#         </p>
#         <table class="price" id="snippet-table">
#          <caption>
#           Tablets Price List
#          </caption>
#          <thead>
#           <tr>
#            <th>
#             Tablet
#            </th>
#            <th>
#             Price
#            </th>
#            <th>
#             Available From
#            </th>
#           </tr>
#          </thead>
#          <tbody>
#           <tr>
#            <td>
#             OnePlus Pad Go Tablet
#            </td>
#            <td>
#             ₹25,999
#            </td>
#            <td>
#             Upcoming
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Lenovo Xiaoxin Pad Pro 12.7
#            </td>
#            <td>
#             ₹18,499
#            </td>
#            <td>
#             Upcoming
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Xiaomi Pad 6 Tablet (8GB RAM + 256GB)
#            </td>
#            <td>
#             ₹28,999
#            </td>
#            <td>
#             Jun, 2023
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Samsung Galaxy Tab S9 FE Plus
#            </td>
#            <td>
#             ₹52,999
#            </td>
#            <td>
#             Upcoming
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Xiaomi Redmi Pad SE Tablet
#            </td>
#            <td>
#             ₹9,999
#            </td>
#            <td>
#             Upcoming
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Realme Pad 2 Tablet
#            </td>
#            <td>
#             ₹19,999
#            </td>
#            <td>
#             Jul, 2023
#            </td>
# ...
#         RAM
#        </option>
#        <option value="rating">
#         Rating
#        </option>
#        <option value="battery">
#         Battery Size
#        </option>
#        <option value="thickness">
#         Thickness
#        </option>
#        <option value="price_drop">
#         Price Drop
#        </option>
#        <!--]-->
#       </select>
#      </div>
#      <div>
#       <svg class="icon" style="" viewbox="0 0 24 24">
#        <path d="M14,12V19.88C14.04,20.18 13.94,20.5 13.71,20.71C13.32,21.1 12.69,21.1 12.3,20.71L10.29,18.7C10.06,18.47 9.96,18.16 10,17.87V12H9.97L4.21,4.62C3.87,4.19 3.95,3.56 4.38,3.22C4.57,3.08 4.78,3 5,3V3H19V3C19.22,3 19.43,3.08 19.62,3.22C20.05,3.56 20.13,4.19 19.79,4.62L14.03,12H14Z">
#        </path>
#       </svg>
#       Filter
#       <!-- -->
#      </div>
#     </div>
#    </main>
#    <!--[-->
#    <!-- -->
#    <!-- -->
#    <footer>
#     <!--[-->
#     <!--[-->
#     <div class="sm-footer">
#      <div class="sm-footer-top">
#       <div>
#        <a class="logo" data-way="" href="/">
#         <img alt="Smartprix" height="60" src="/img/sm_small.png" width="186"/>
#        </a>
#        <div class="sm-footer-social">
#         <!--[-->
#         <a href="/about/contact" rel="nofollow noopener" target="_blank" title="Contact Us">
#          <svg class="icon" style="" viewbox="0 0 24 24">
#           <path d="M20,8L12,13L4,8V6L12,11L20,6M20,4H4C2.89,4 2,4.89 2,6V18A2,2 0 0,0 4,20H20A2,2 0 0,0 22,18V6C22,4.89 21.1,4 20,4Z">
#           </path>
#          </svg>
#         </a>
#         <a href="https://www.facebook.com/smartprix" rel="nofollow noopener" target="_blank" title="Facebook">
#          <svg class="icon" style="" viewbox="0 0 24 24">
#           <path d="M12 2.04C6.5 2.04 2 6.53 2 12.06C2 17.06 5.66 21.21 10.44 21.96V14.96H7.9V12.06H10.44V9.85C10.44 7.34 11.93 5.96 14.22 5.96C15.31 5.96 16.45 6.15 16.45 6.15V8.62H15.19C13.95 8.62 13.56 9.39 13.56 10.18V12.06H16.34L15.89 14.96H13.56V21.96A10 10 0 0 0 22 12.06C22 6.53 17.5 2.04 12 2.04Z">
#           </path>
#          </svg>
#         </a>
#         <a href="https://twitter.com/smartprix" rel="nofollow noopener" target="_blank" title="Twitter">
#          <svg class="icon" style="" viewbox="0 0 24 24">
#           <path d="M22.46,6C21.69,6.35 20.86,6.58 20,6.69C20.88,6.16 21.56,5.32 21.88,4.31C21.05,4.81 20.13,5.16 19.16,5.36C18.37,4.5 17.26,4 16,4C13.65,4 11.73,5.92 11.73,8.29C11.73,8.63 11.77,8.96 11.84,9.27C8.28,9.09 5.11,7.38 3,4.79C2.63,5.42 2.42,6.16 2.42,6.94C2.42,8.43 3.17,9.75 4.33,10.5C3.62,10.5 2.96,10.3 2.38,10C2.38,10 2.38,10 2.38,10.03C2.38,12.11 3.86,13.85 5.82,14.24C5.46,14.34 5.08,14.39 4.69,14.39C4.42,14.39 4.15,14.36 3.89,14.31C4.43,16 6,17.26 7.89,17.29C6.43,18.45 4.58,19.13 2.56,19.13C2.22,19.13 1.88,19.11 1.54,19.07C3.44,20.29 5.7,21 8.12,21C16,21 20.33,14.46 20.33,8.79C20.33,8.6 20.33,8.42 20.32,8.23C21.16,7.63 21.88,6.87 22.46,6Z">
#           </path>
#          </svg>
#         </a>
#         <a href="https://www.youtube.com/channel/UCvkQPgMQX_C1i9JnDZmOY2Q" rel="nofollow noopener" target="_blank" title="YouTube">
#          <svg class="icon" style="" viewbox="0 0 24 24">
#           <path d="M10,15L15.19,12L10,9V15M21.56,7.17C21.69,7.64 21.78,8.27 21.84,9.07C21.91,9.87 21.94,10.56 21.94,11.16L22,12C22,14.19 21.84,15.8 21.56,16.83C21.31,17.73 20.73,18.31 19.83,18.56C19.36,18.69 18.5,18.78 17.18,18.84C15.88,18.91 14.69,18.94 13.59,18.94L12,19C7.81,19 5.2,18.84 4.17,18.56C3.27,18.31 2.69,17.73 2.44,16.83C2.31,16.36 2.22,15.73 2.16,14.93C2.09,14.13 2.06,13.44 2.06,12.84L2,12C2,9.81 2.16,8.2 2.44,7.17C2.69,6.27 3.27,5.69 4.17,5.44C4.64,5.31 5.5,5.22 6.82,5.16C8.12,5.09 9.31,5.06 10.41,5.06L12,5C16.19,5 18.8,5.16 19.83,5.44C20.73,5.69 21.31,6.27 21.56,7.17Z">
#           </path>
#          </svg>
#         </a>
#         <a href="https://www.instagram.com/smartprix/" rel="nofollow noopener" target="_blank" title="Instagram">
#          <svg class="icon" style="" viewbox="0 0 24 24">
#           <path d="M7.8,2H16.2C19.4,2 22,4.6 22,7.8V16.2A5.8,5.8 0 0,1 16.2,22H7.8C4.6,22 2,19.4 2,16.2V7.8A5.8,5.8 0 0,1 7.8,2M7.6,4A3.6,3.6 0 0,0 4,7.6V16.4C4,18.39 5.61,20 7.6,20H16.4A3.6,3.6 0 0,0 20,16.4V7.6C20,5.61 18.39,4 16.4,4H7.6M17.25,5.5A1.25,1.25 0 0,1 18.5,6.75A1.25,1.25 0 0,1 17.25,8A1.25,1.25 0 0,1 16,6.75A1.25,1.25 0 0,1 17.25,5.5M12,7A5,5 0 0,1 17,12A5,5 0 0,1 12,17A5,5 0 0,1 7,12A5,5 0 0,1 12,7M12,9A3,3 0 0,0 9,12A3,3 0 0,0 12,15A3,3 0 0,0 15,12A3,3 0 0,0 12,9Z">
#           </path>
#          </svg>
#         </a>
#         <a href="https://smpx.to/telegram?utm_source=desktop_footer" rel="nofollow noopener" target="_blank" title="Telegram">
#          <svg class="icon" style="" viewbox="0 0 24 24">
#           <path d="M20.7 3.7 2.9 10.6c-1.2.4-1.2 1.1-.2 1.4l4.6 1.4 10.5-6.6c.5-.3 1-.1.6.2l-8.6 7.7-.3 4.7c.5 0 .7-.2 1-.5l2.2-2.1 4.6 3.4c.8.4 1.4.2 1.6-.8l3-14.2c.4-1.3-.4-1.8-1.2-1.5z">
#           </path>
#          </svg>
#         </a>
#         <a href="https://www.smartprix.com/bytes/feed/" rel="nofollow noopener" target="_blank" title="RSS Feed">
#          <svg class="icon" style="" viewbox="0 0 24 24">
#           <path d="M6.18,15.64A2.18,2.18 0 0,1 8.36,17.82C8.36,19 7.38,20 6.18,20C5,20 4,19 4,17.82A2.18,2.18 0 0,1 6.18,15.64M4,4.44A15.56,15.56 0 0,1 19.56,20H16.73A12.73,12.73 0 0,0 4,7.27V4.44M4,10.1A9.9,9.9 0 0,1 13.9,20H11.07A7.07,7.07 0 0,0 4,12.93V10.1Z">
#           </path>
#          </svg>
#         </a>
#         <a href="https://smpx.to/app?utm_source=desktop_footer" rel="nofollow noopener" target="_blank" title="Android App">
#          <svg class="icon" style="" viewbox="0 0 24 24">
#           <path d="M3,20.5V3.5C3,2.91 3.34,2.39 3.84,2.15L13.69,12L3.84,21.85C3.34,21.6 3,21.09 3,20.5M16.81,15.12L6.05,21.34L14.54,12.85L16.81,15.12M20.16,10.81C20.5,11.08 20.75,11.5 20.75,12C20.75,12.5 20.53,12.9 20.18,13.18L17.89,14.5L15.39,12L17.89,9.5L20.16,10.81M6.05,2.66L16.81,8.88L14.54,11.15L6.05,2.66Z">
#           </path>
#          </svg>
#         </a>
#         <!--]-->
#        </div>
#       </div>
#       <div class="sm-footer-nav">
#        <!--[-->
#        <div>
#         <h3>
#          Categories
#         </h3>
#         <!--[-->
#         <a data-way="" href="/mobiles">
#          Mobile Phones
#         </a>
#         <a data-way="" href="/tablets">
#          Tablets
#         </a>
#         <a data-way="" href="/mobile_headphones">
#          Earphones
#         </a>
#         <a data-way="" href="/laptops">
#          Laptops
#         </a>
#         <a data-way="" href="/tvs">
#          TVs
#         </a>
#         <a data-way="" href="/cameras">
#          Cameras
#         </a>
#         <a data-way="" href="/air_conditioners">
#          ACs
#         </a>
#         <a data-way="" href="/refrigerators">
#          Fridge
#         </a>
#         <a data-way="" href="/washing_machines">
#          Washing Machines
#         </a>
#         <a data-way="" href="/trimmers">
#          Trimmers
#         </a>
#         <a data-way="" href="/induction_cooktops">
#          Induction Cooktops
#         </a>
#         <a data-way="" href="/deals">
#          Deals
#         </a>
#         <!--]-->
#        </div>
#        <div>
#         <h3>
#          Mobile Brands
#         </h3>
#         <!--[-->
#         <a data-way="" href="/mobiles/samsung-brand">
#          Samsung Mobiles
#         </a>
#         <a data-way="" href="/mobiles/xiaomi-brand">
#          Redmi / Mi Mobiles
#         </a>
#         <a data-way="" href="/mobiles/realme-brand">
#          Realme Mobiles
#         </a>
#         <a data-way="" href="/mobiles/vivo-brand">
#          Vivo Mobiles
#         </a>
#         <a data-way="" href="/mobiles/motorola-brand">
#          Motorola Mobiles
#         </a>
#         <a data-way="" href="/mobiles/oneplus-brand">
#          OnePlus Mobiles
#         </a>
#         <a data-way="" href="/mobiles/oppo-brand">
#          Oppo Mobiles
#         </a>
#         <a data-way="" href="/mobiles/apple-brand">
#          Apple iPhones
#         </a>
#         <a data-way="" href="/mobiles/infinix-brand">
#          Infinix Mobiles
#         </a>
#         <a data-way="" href="/mobiles/poco-brand">
#          Poco Mobiles
#         </a>
#         <a data-way="" href="/mobiles/tecno-brand">
#          Tecno Mobiles
#         </a>
#         <a data-way="" href="/mobiles/nokia-brand">
#          Nokia Mobiles
#         </a>
#         <!--]-->
#        </div>
#        <div>
#         <h3>
#          Mobile Lists
#         </h3>
#         <!--[-->
#         <a data-way="" href="/mobiles/smartphone-type">
#          Smartphones
#         </a>
#         <a data-way="" href="/mobiles/with-5g">
#          5G Mobiles
#         </a>
#         <a data-way="" href="/mobiles/with-4g">
#          4G Mobiles
#         </a>
#         <a data-way="" href="/mobiles/latest-mobiles">
#          New Mobiles
#         </a>
#         <a data-way="" href="/mobiles/upcoming-stock">
#          Upcoming Mobiles
#         </a>
#         <a data-way="" href="/mobiles/4_gb_above-ram">
#          4GB RAM Mobiles
#         </a>
#         <a data-way="" href="/mobiles/6_gb_above-ram">
#          6GB RAM Mobiles
#         </a>
#         <a data-way="" href="/mobiles/android-os">
#          Android Mobiles
#         </a>
#         <a data-way="" href="/mobiles/with-fingerprint">
#          Fingerprint Phones
#         </a>
#         <a data-way="" href="/mobiles/with-waterproof">
#          Waterproof Mobiles
#         </a>
#         <a data-way="" href="/mobiles/5000_mah_above-battery_size">
#          5000 mAh Mobiles
#         </a>
#         <a data-way="" href="/mobiles/keypad-mobiles-list">
#          Keypad Mobiles
#         </a>
#         <!--]-->
#        </div>
#        <div>
#         <h3>
#          About
#         </h3>
#         <!--[-->
#         <a data-way="" href="/about/smartprix">
#          About Smartprix
#         </a>
#         <a data-way="" href="/about/us">
#          Team
#         </a>
#         <a data-way="" href="/about/jobs">
#          Jobs
#         </a>
#         <a data-way="" href="/about/contact">
#          Contact Us
#         </a>
#         <a data-way="" href="/about/help">
#          Help
#         </a>
#         <a data-way="" href="/about/tools">
#          Tools
#         </a>
#         <a data-way="" href="/mobiles">
#          Find A Mobile
#         </a>
#         <a data-way="" href="/mobiles/compare.php">
#          Compare Mobiles
#         </a>
#         <a data-way="" href="/bytes/">
#          Latest News
#         </a>
#         <!--]-->
#        </div>
#        <!--]-->
#       </div>
#      </div>
#      <div class="sm-footer-c">
#       <div style="flex:1;">
#        Copyright © 2023,
#        <a data-way="" href="/">
#         Smartprix.com
#        </a>
#        . All Rights Reserved
#       </div>
#       <div>
#        <a data-way="" href="/about/contact">
#         Contact Us
#        </a>
#        <span style="margin:0 10px;">
#         •
#        </span>
#        <a data-way="" href="/about/privacy-policy">
#         Privacy Policy
#        </a>
#        <span style="margin:0 10px;">
#         •
#        </span>
#        <a data-way="" href="/about/terms-of-services">
#         Terms of Services
#        </a>
#       </div>
#      </div>
#     </div>
#     <!--]-->
#     <!--]-->
#    </footer>
#    <!-- -->
#    <!-- -->
#    <!--]-->
#    <div class="loading">
#     <!-- -->
#    </div>
#    <div>
#     <div class="sm-drawer d-left">
#      <div class="content">
#       <!-- -->
#      </div>
#     </div>
#     <!-- -->
#     <!-- -->
#    </div>
#    <!--]-->
#   </div>
#   <script id="__WAY_JSON__" type="application/json">
#    {"$way":{"url":"/tablets","component":"FinderPage","props":{"item":{"id":"fp1u7jots4e","title":"Tablets","category":{"id":14,"name":"Tablets","singularName":"Tablet","slug":"tablets","parent":{"id":141,"name":"Mobiles And Tablets"},"finderSortFields":[{"url":"rel","text":"Relevance"},{"url":"pop","text":"Popularity"},{"url":"price:1","text":"Price Low To High"},{"url":"price","text":"Price High To Low"},{"url":"date","text":"Date"},{"url":"spec_score","text":"Spec Score"},{"url":"camera","text":"Camera Resolution"},{"url":"cpu","text":"CPU Speed"},{"url":"display","text":"Display Size"},{"url":"display-res","text":"Display Resolution"},{"url":"display-ppi","text":"Display PPI"},{"url":"mem","text":"Inbuilt Memory"},{"url":"ram","text":"RAM"},{"url":"rating","text":"Rating"},{"url":"battery","text":"Battery Size"},{"url":"thickness","text":"Thickness"},{"url":"price_drop","text":"Price Drop"}],"finderPriceRanges":[0,3000,5000,7000,10000,12000,15000,20000,25000,30000,40000,50000,60000,75000,100000]},"isCategoryLanding":true,"subItemType":"CATEGORY_LANDING","descriptions":{"h1":"Tablets Price List in India","top":"<p>Discover our extensive collection of the best tablets available online in India, all at the lowest prices. If you're looking for a device with a big screen and a mobile operating system, a tablet may be perfect for you. Tablets are ideal for those who want a secondary screen for reading, browsing, watching movies or TV shows, scrolling through social media apps, and, most importantly, for enhancing the gaming experience with clear visuals and high-quality graphics. With a wide range of tablets available in different designs and price ranges, buyers can easily find the right tablet to meet their budget and demands.</p>\n<p>We have curated a list of all the latest and upcoming tablets from top brands such as Apple, Samsung, Oppo, Vivo, and many more. Our list includes detailed specifications and features, making it easier for you to select the right tablet for your needs. You can also compare tablets from different brands based on price, specs, and features. Our price list is updated regularly to ensure that you always have access to the latest information. Check out our collection now to find the perfect tablet for you. This price list was last updated on September 28, 2023.</p>\n<p><strong>Also See</strong>: <a href=\"https://www.smartprix.com/tablets/apple-brand\" target=\"_blank\">Apple iPads</a> • <a href=\"https://www.smartprix.com/tablets/samsung-brand\" target=\"_blank\">Samsung Tablets</a> • <a href=\"https://www.smartprix.com/tablets/lenovo-brand\" target=\"_blank\">Lenovo Tablets</a> • <a href=\"https://www.smartprix.com/tablets/xiaomi-brand\" target=\"_blank\">Xiaomi Tablets</a> • <a href=\"https://www.smartprix.com/tablets/realme-brand\" target=\"_blank\">Realme Tablets</a></p><table id=\"snippet-table\" class=\"price\"><caption>Tablets Price List</caption><thead><tr><th>Tablet</th><th>Price</th><th>Available From</th></tr></thead><tbody><tr><td>OnePlus Pad Go Tablet</td><td>₹25,999</td><td>Upcoming</td></tr><tr><td>Lenovo Xiaoxin Pad Pro 12.7</td><td>₹18,499</td><td>Upcoming</td></tr><tr><td>Xiaomi Pad 6 Tablet (8GB RAM + 256GB)</td><td>₹28,999</td><td>Jun, 2023</td></tr><tr><td>Samsung Galaxy Tab S9 FE Plus</td><td>₹52,999</td><td>Upcoming</td></tr><tr><td>Xiaomi Redmi Pad SE Tablet</td><td>₹9,999</td><td>Upcoming</td></tr><tr><td>Realme Pad 2 Tablet</td><td>₹19,999</td><td>Jul, 2023</td></tr><tr><td>Lenovo Xiaoxin Pad Pro 12.7</td><td>₹20,500</td><td>Upcoming</td></tr><tr><td>Xiaomi Pad 6 Pro Tablet</td><td>₹29,990</td><td>Upcoming</td></tr><tr><td>Samsung Galaxy Tab A9 Plus Tablet</td><td>₹25,990</td><td>Upcoming</td></tr><tr><td>Realme Pad X Tablet (6GB RAM+ 128GB)</td><td>₹25,999</td><td>Aug, 2022</td></tr></tbody></table>"},"topDynamicContent":[{"title":"Shop By Brands","bg":"aliceblue","type":"categories","scroll":true,"items":[{"name":"Samsung","link":"/tablets/samsung-brand","imageId":"Mpmb153 ...
#   </script>
#   <script>
#    window._server_time_=1695902348207;(window._extra_={})._dap_={"d_finder_below_title_box":{"w":728,"h":90},"d_finder_below_load_more":{"w":728,"h":90},"d_finder_sidebar_top":{"w":320,"h":50},"d_finder_sidebar_below_filters":{"w":300,"h":250},"$p":"d","$cl":150,"$cr":60};
#   </script>
#   <iframe src="https://c2b3af20f10eb6dd821aced494595b85.safeframe.googlesyndication.com/safeframe/1-0-40/html/container.html" style="visibility: hidden; display: none;">
#   </iframe>
#   <div class="sm-overlay" style="z-index: 6;">
#   </div>
#   <iframe id="google_ads_top_frame" name="google_ads_top_frame" style="display: none; position: fixed; left: -999px; top: -999px; width: 0px; height: 0px;">
#   </iframe>
#   <iframe height="0" src="https://www.google.com/recaptcha/api2/aframe" style="display: none;" width="0">
#   </iframe>
#  </body>
# </html>

# %%
containers=soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'})

# %%
name=[]
price=[]
specs=[]
sim=[]
battery=[]
networks=[]
screen_size=[]
processor=[]
camera=[]
ram=[]
os=[]
for i in containers:
 
    name.append(i.find_all('h2')[0].text)
   
    price.append(i.find_all('span',{'class':'price'})[0].text.replace(',',''))
    
       
    x=i.find_all('div',{'class':'score rank-2-bg'})
    for w in x:
        if w:
            specs.append(w.find('b').text)
    y=i.find_all('div',{'class':'score rank-1-bg'})
    for j in y:

        specs.append(i.find('b').text)
    z=i.find_all('div',{'class':'score rank-3-bg'})
    for k in z:

        specs.append(i.find('b').text)
            

    
    m=i.find_all('ul',{'class':'sm-feat specs'})
    for u in m:

           
        sim.append(u.find_all('li')[0].text)
            
   
  
        networks.append(u.find_all('li')[1].text)
       
        processor.append(u.find_all('li')[2].text)

        ram.append(u.find_all('li')[3].text)
        
        battery.append(u.find_all('li')[4].text)
        
        screen_size.append(u.find_all('li')[5].text)
       
        camera.append(u.find_all('li')[6].text)
       
        os.append(u.find_all('li')[7].text)
        
specs.insert(198,77) 
specs.insert(199,80)
df1=pd.DataFrame({'name':name,
                  'price':price,
                'specs':specs,
                'sim':sim,
                'battery':battery,
                'ram':ram,
                'networks':networks,
                'processor':processor,
                 'screen_size':screen_size,
                 'os':os,
                 'camera':camera
                })

# %%
df1.shape
# Out:
# (200, 11)

# %%
df1.isnull().sum()
# Out:
# name           0
# price          0
# specs          0
# sim            0
# battery        0
# ram            0
# networks       0
# processor      0
# screen_size    0
# os             0
# camera         0
# dtype: int64

# %%
df1.head()
# Out:
#                                     name   price specs         sim  \
# 0                  OnePlus Pad Go Tablet  ₹25999    77  Single Sim
# 1            Lenovo Xiaoxin Pad Pro 12.7  ₹18499    81  Single Sim
# 2  Xiaomi Pad 6 Tablet (8GB RAM + 256GB)  ₹28999    74       Wi-Fi
# 3          Samsung Galaxy Tab S9 FE Plus  ₹52999    91  Single Sim
# 4             Xiaomi Redmi Pad SE Tablet   ₹9999    68       Wi-Fi
#
#                                     battery                       ram  \
# 0   8000 mAh Battery with 33W Fast Charging  8 GB RAM, 256 GB inbuilt
# 1  10200 mAh Battery with 20W Fast Charging  8 GB RAM, 128 GB inbuilt
# 2   8840 mAh Battery with 33W Fast Charging  8 GB RAM, 256 GB inbuilt
# 3  10900 mAh Battery with 45W Fast Charging  8 GB RAM, 256 GB inbuilt
# 4   8000 mAh Battery with 10W Fast Charging  4 GB RAM, 128 GB inbuilt
#
#                    networks                                     processor  \
# 0             3G, 4G, Wi-Fi       Helio G99, Octa Core, 2.2 GHz Processor
# 1  3G, 4G, 5G, VoLTE, Wi-Fi  Snapdragon 870, Octa Core, 3.2 GHz Processor
# 2                     No 3G  Snapdragon 870, Octa Core, 3.2 GHz Processor
# 3  3G, 4G, 5G, VoLTE, Wi-Fi    Exynos  1380, Octa Core, 2.4 GHz Processor
# 4                     No 3G  Snapdragon 680, Octa Core, 2.4 GHz Processor
#
#                                     screen_size  \
# 0  11.35 inches, 2000 x 2800 px, 120 Hz Display
# 1   12.7 inches, 2944 x 1840 px, 144 Hz Display
# 2     11 inches, 1800 x 2880 px, 144 Hz Display
# 3   12.4 inches, 1600 x 2560 px, 120 Hz Display
# 4      11 inches, 1200 x 1920 px, 90 Hz Display
#
#                                  os  \
# 0                       Android v13
# 1  Memory Card Supported, upto 1 TB
# 2                       Android v13
# 3  Memory Card Supported, upto 1 TB
# 4  Memory Card Supported, upto 1 TB
#
#                                         camera
# 0                8 MP Rear & 8 MP Front Camera
# 1               8 MP Rear & 13 MP Front Camera
# 2               13 MP Rear & 8 MP Front Camera
# 3  12 MP + 8 MP Dual Rear & 12 MP Front Camera
# 4                8 MP Rear & 5 MP Front Camera

# %%
df1.to_csv('tablets.csv')
